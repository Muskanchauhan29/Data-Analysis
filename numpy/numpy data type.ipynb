# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([1., 2., 3., 4., 5., 6.])

# %%
arr.nbytes
# Out:
# 48

# %%
result = arr ** 2
print(result)
# Out:
# [ 1  4  9 16 25 36]

# %%
result + 10
# Out:
# array([11, 14, 19, 26, 35, 46])
