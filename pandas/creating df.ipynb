# %%
import pandas as pd

# %%
data = [['harry', 34],['mussu',44], ['muskan',99]]

# %%
data
# Out:
# [['harry', 34], ['mussu', 44], ['muskan', 99]]

# %%
pd.DataFrame(data, columns = ["Name", "Marks"])
# Out:
#      Name  Marks
# 0   harry     34
# 1   mussu     44
# 2  muskan     99

# %%
df = pd.read_excel("data.xlsx")

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.virtual_documents',
#  'creating df.ipynb',
#  'data.xlsx',
#  'dataanalysis.ipynb',
#  'pandas.ipynb']

# %%
import pandas as pd

df = pd.read_excel("data.xlsx")
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

df = pd.read_excel("data.xlsx")

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.shape
# Out:
# (0, 0)

# %%
import pandas as pd

df = pd.read_excel("data.xlsx", sheet_name="Sheet1")
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

xls = pd.ExcelFile("data.xlsx")
print(xls.sheet_names)
# Out:
# ['Sheet1']

# %%
df = pd.read_excel("data2.xlsx")

# %%
df
# Out:
#    name  school  marks
# 0     a       1     88
# 1     b       2     77
# 2     c       3     66
# 3     d       4     55
# 4     e       5     44
# 5     f       6     33
# 6     g       7     22
# 7     h       8     11

# %%
print(df)
# Out:
#    name  school  marks
# 0     a       1     88
# 1     b       2     77
# 2     c       3     66
# 3     d       4     55
# 4     e       5     44
# 5     f       6     33
# 6     g       7     22
# 7     h       8     11
