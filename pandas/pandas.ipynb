# %%
import pandas as pd

# %%
conda install pandas
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\muskc\anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2026.01.04         |  py313haa95532_0         148 KB
#     openssl-3.5.5              |       hbb43b14_0         8.9 MB
#     ------------------------------------------------------------
#                                            Total:         9.0 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.11.4-haa95532_0 --> 2025.12.2-haa95532_0
#   certifi                        2025.11.12-py313haa95532_0 --> 2026.01.04-py313haa95532_0
# ...

# %%
s = pd.Series([71, 45, 66, 78, 93])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0    71
# 1    45
# 2    66
# 3    78
# 4    93
# dtype: int64

# %%
s1 = pd.Series([71, 45, 66, 78, 93], index = ["harry", "shub", "rohan" ,"akash", "mussu"])

# %%
s1
# Out:
# harry    71
# shub     45
# rohan    66
# akash    78
# mussu    93
# dtype: int64

# %%
s1[mussu]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s1[mussu]
#
# NameError: name 'mussu' is not defined

# %%
s1["mussu']
# Out:
#   Cell In[10], line 1
#     s1["mussu']
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1["mussu"]
# Out:
# np.int64(93)
